# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os

# %%
testing_letter = pd.read_csv(r'C:\Users\aarti\Downloads\archive (10)\emnist-letters-test.csv')
training_letter = pd.read_csv(r'C:\Users\aarti\Downloads\archive (10)\emnist-letters-train.csv')

# %%
print(training_letter.shape)
print(testing_letter.shape)
# Out:
# (88799, 785)
# (14799, 785)

# %%
y1 = np.array(training_letter.iloc[:,0].values)
x1 = np.array(training_letter.iloc[:,1:].values)

y2 = np.array(testing_letter.iloc[:,0].values)
x2 = np.array(testing_letter.iloc[:,1:].values)
print(y1.shape)
print(x1.shape)
# Out:
# (88799,)
# (88799, 784)

# %%
import matplotlib.pyplot as plt 
fig,axes = plt.subplots(3,5,figsize=(10,8))
for i,ax in enumerate(axes.flat):
    ax.imshow(x1[i].reshape([28,28]))

# %%
import tensorflow as tf

# %%
train_images = x1 / 255.0
test_images = x2 / 255.0

train_images_number = train_images.shape[0]
train_images_height = 28
train_images_width = 28
train_images_size = train_images_height*train_images_width

train_images = train_images.reshape(train_images_number, train_images_height, train_images_width, 1)

test_images_number = test_images.shape[0]
test_images_height = 28
test_images_width = 28
test_images_size = test_images_height*test_images_width

test_images = test_images.reshape(test_images_number, test_images_height, test_images_width, 1)

# %%
number_of_classes = 37

y1 = tf.keras.utils.to_categorical(y1, number_of_classes)
y2 = tf.keras.utils.to_categorical(y2, number_of_classes)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau,ModelCheckpoint
from sklearn.model_selection import train_test_split

# %%
train_x,test_x,train_y,test_y = train_test_split(train_images,y1,test_size=0.2,random_state = 42)

# %%
model = tf.keras.Sequential([ 
    tf.keras.layers.Conv2D(32,3,input_shape=(28,28,1)),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(input_shape=(28,28,1)),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(128,activation='relu'),
    tf.keras.layers.Dense(number_of_classes,activation='softmax')
])

# %%
model.compile(optimizer='rmsprop',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
MCP = ModelCheckpoint('Best_points.h5',verbose=1,save_best_only=True,monitor='val_accuracy',mode='max')
ES = EarlyStopping(monitor='val_accuracy',min_delta=0,verbose=0,restore_best_weights = True,patience=3,mode='max')
RLP = ReduceLROnPlateau(monitor='val_loss',patience=3,factor=0.2,min_lr=0.0001)

# %%
history = model.fit(train_x,train_y,epochs=10,validation_data=(test_x,test_y),callbacks=[MCP,ES,RLP])
# Out:
# Epoch 1/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.5513 - accuracy: 0.8269
# Epoch 00001: val_accuracy improved from -inf to 0.87872, saving model to Best_points.h5
# 2220/2220 [==============================] - 141s 60ms/step - loss: 0.5513 - accuracy: 0.8269 - val_loss: 0.3849 - val_accuracy: 0.8787 - lr: 0.0010
# Epoch 2/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.2775 - accuracy: 0.9104
# Epoch 00002: val_accuracy improved from 0.87872 to 0.90231, saving model to Best_points.h5
# 2220/2220 [==============================] - 128s 57ms/step - loss: 0.2775 - accuracy: 0.9104 - val_loss: 0.2993 - val_accuracy: 0.9023 - lr: 0.0010
# Epoch 3/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.2131 - accuracy: 0.9287
# Epoch 00003: val_accuracy improved from 0.90231 to 0.90777, saving model to Best_points.h5
# 2220/2220 [==============================] - 127s 57ms/step - loss: 0.2131 - accuracy: 0.9287 - val_loss: 0.3311 - val_accuracy: 0.9078 - lr: 0.0010
# Epoch 4/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.1818 - accuracy: 0.9381
# Epoch 00004: val_accuracy did not improve from 0.90777
# 2220/2220 [==============================] - 123s 55ms/step - loss: 0.1818 - accuracy: 0.9381 - val_loss: 0.3641 - val_accuracy: 0.9042 - lr: 0.0010
# Epoch 5/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.1658 - accuracy: 0.9439
# Epoch 00005: val_accuracy did not improve from 0.90777
# 2220/2220 [==============================] - 126s 57ms/step - loss: 0.1658 - accuracy: 0.9439 - val_loss: 0.4467 - val_accuracy: 0.8997 - lr: 0.0010
# Epoch 6/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0793 - accuracy: 0.9698
# Epoch 00006: val_accuracy improved from 0.90777 to 0.91627, saving model to Best_points.h5
# 2220/2220 [==============================] - 127s 57ms/step - loss: 0.0793 - accuracy: 0.9698 - val_loss: 0.3573 - val_accuracy: 0.9163 - lr: 2.0000e-04
# Epoch 7/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0650 - accuracy: 0.9757
# Epoch 00007: val_accuracy improved from 0.91627 to 0.91836, saving model to Best_points.h5
# 2220/2220 [==============================] - 123s 56ms/step - loss: 0.0650 - accuracy: 0.9757 - val_loss: 0.3649 - val_accuracy: 0.9184 - lr: 2.0000e-04
# Epoch 8/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0596 - accuracy: 0.9768 ETA: 1s - loss: 0.0599 - accuracy
# Epoch 00008: val_accuracy did not improve from 0.91836
# 2220/2220 [==============================] - 125s 56ms/step - loss: 0.0596 - accuracy: 0.9768 - val_loss: 0.4168 - val_accuracy: 0.9164 - lr: 2.0000e-04
# Epoch 9/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0494 - accuracy: 0.9808
# Epoch 00009: val_accuracy did not improve from 0.91836
# 2220/2220 [==============================] - 124s 56ms/step - loss: 0.0494 - accuracy: 0.9808 - val_loss: 0.4074 - val_accuracy: 0.9149 - lr: 1.0000e-04
# Epoch 10/10
# 2220/2220 [==============================] - ETA: 0s - loss: 0.0479 - accuracy: 0.9810
# Epoch 00010: val_accuracy did not improve from 0.91836
# 2220/2220 [==============================] - 125s 56ms/step - loss: 0.0479 - accuracy: 0.9810 - val_loss: 0.4317 - val_accuracy: 0.9152 - lr: 1.0000e-04

# %%
q = len(history.history['accuracy'])

plt.figsize=(10,10)
sns.lineplot(x = range(1,1+q),y = history.history['accuracy'], label='Accuracy')
sns.lineplot(x = range(1,1+q),y = history.history['val_accuracy'], label='Val_Accuracy')
plt.xlabel('epochs')
plt.ylabel('Accuracy')
# Out:
# Text(0, 0.5, 'Accuracy')
